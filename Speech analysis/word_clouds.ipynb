# %% [markdown]
# <a href="https://colab.research.google.com/github/GemThornley/Climate-Hunters/blob/main/word_clouds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import necessary libraries

#for importing data and wrangling
import pandas as pd
import numpy as np
from matplotlib import cm

#for plotting images & adjusting colors
import matplotlib.pyplot as plt
import matplotlib as mpl
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image

import os

if not os.path.exists("images"):
    os.mkdir("images")

# %%
df = pd.read_csv("/content/important1.csv", index_col=0)
df.head()
# Out:
#              sustainable  carbon  ...  ultraviolet radiation  non-renewable energy
# Conserative        11491    9141  ...                      2                     0
# Lib Dem             2300    2839  ...                      1                     0
# Green                 85     370  ...                      0                     0
# Labour             11607   10749  ...                      2                     0
# NaN                25483   23099  ...                      3                     0
#
# [5 rows x 79 columns]

# %%
# !pip install chart_studio
import chart_studio

text=df.head()

text2_dict=df.iloc[0].sort_values(ascending=False).to_dict()

wordcloud = WordCloud(width=800, height=500,background_color='black', colormap='YlGn')

cloud = wordcloud.generate_from_frequencies(text2_dict)
plt.savefig('saved1.jpg')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.figure( figsize=(40,20) )
cloud.to_file('newest_Tories.png')
plt.show()

# %% [markdown]
# # New section

# %%
# create a pandas Series of the top 4000 most frequent words
text=df.head()

text2_dict=df.iloc[1].sort_values(ascending=False).to_dict()

wordcloud = WordCloud(width=800, height=500,background_color='black', colormap='YlGn')

cloud = wordcloud.generate_from_frequencies(text2_dict)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
cloud.to_file('newest_LibDem.png')
plt.show()

# %%
# create a pandas Series of the top 4000 most frequent words
text=df.head()

text2_dict=df.iloc[2].sort_values(ascending=False).to_dict()

wordcloud = WordCloud(width=800, height=500,background_color='black', colormap='YlGn')

cloud = wordcloud.generate_from_frequencies(text2_dict)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
cloud.to_file('newest_Green.png')
plt.show()

# %%
# create a pandas Series of the top 4000 most frequent words
text=df.head()

text2_dict=df.iloc[3].sort_values(ascending=False).to_dict()
wordcloud = WordCloud(width=800, height=500,background_color='black', colormap='YlGn')


wordcloud.generate_from_frequencies(text2_dict)

cloud = wordcloud.generate_from_frequencies(text2_dict)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
cloud.to_file('newest_Labour.png')
plt.show()
