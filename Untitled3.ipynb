# %% [markdown]
# <a href="https://colab.research.google.com/github/GemThornley/Climate-Hunters/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
 
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from matplotlib import *

df = pd.read_csv("/content/new for barchart.csv")
df.head()

plt.figure(figsize=(150,70))
plt.xticks(rotation=90, fontsize=80)
plt.xlim(-0.5,len(df)-.5)
plt.bar(x=df['Words'],
 
        height=df['Total Use'])
# Out:
# <BarContainer object of 85 artists>

# %%
import plotly.graph_objects as go
# !pip install chart_studio
import chart_studio
df = pd.read_csv("/content/new for barchart.csv")

fig = go.Figure()
fig.add_trace(go.Bar(x=df['Words'], y=df["Total Use"], hovertemplate="%{x}<br>Uses = %{y}<extra></extra>", marker=dict(color = "green")))
fig.update_layout(
    font=dict(
        family="Arial",
        size=3,
        color="Black"
    )
)
fig.update_layout(
    title="Word Frequency: Combined Parties Overall",
    xaxis_title="Words",
    yaxis_title="Total Frequency",
    title_font_size = 20,
    font=dict(
        family="Arial",
        size=8,
        color="Black"
    )
)


fig.show()


username = 'GemmaThornley' 
api_key = 'tkCXLQ3xImGn7POF3DZ7'
chart_studio.tools.set_credentials_file(username=username, api_key=api_key)
import chart_studio.plotly as py
py.plot(fig, filename = 'Definitely a Graph', auto_open=True)
# Out:
# ...
#      |████████████████████████████████| 64 kB 2.0 MB/s
# ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="57eb2c77-e69e-4767-ab88-8f6b5f2fc32e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("57eb2c77-e69e-4767-ab88-8f6b5f2fc32e")) {
#                     Plotly.newPlot(
#                         '57eb2c77-e69e-4767-ab88-8f6b5f2fc32e',
# ...

# %%
df = pd.read_csv("/politicians totals.csv")
df.head()

plt.figure(figsize=(150,70))
plt.xticks(rotation=90, fontsize=80)
plt.xlim(-0.5,len(df)-.5)
plt.bar(x=df['Words'],
 
        height=df['Total '])
# Out:
# <BarContainer object of 92 artists>

# %%
df = pd.read_csv("/content/politicians totals half.csv")
df.head()

fig = go.Figure()
fig.add_trace(go.Bar(x=df['Words'], y=df["Total"], hovertemplate="%{x}<br>Uses = %{y}<extra></extra>", marker=dict(color = "green")))
fig.update_layout(
    font=dict(
        family="Arial",
        size=3,
        color="Black"
    )
)
fig.update_layout(
    title="Word Frequency combined top politicians ",
    xaxis_title="Words",
    yaxis_title="Total Frequency",
    title_font_size = 20,
    font=dict(
        family="Arial",
        size=15,
        color="Black"
    )
)


fig.show()


username = 'GemmaThornley' 
api_key = 'tkCXLQ3xImGn7POF3DZ7'
chart_studio.tools.set_credentials_file(username=username, api_key=api_key)
import chart_studio.plotly as py
py.plot(fig, filename = 'First Graph', auto_open=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8bf6193a-c61b-463d-8614-e2ba0f69871d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8bf6193a-c61b-463d-8614-e2ba0f69871d")) {
#                     Plotly.newPlot(
#                         '8bf6193a-c61b-463d-8614-e2ba0f69871d',
# ...

# %%
import plotly.graph_objects as go
Words=["environmental","carbon","climate change","emissions","fossil fuel","sustainable","electricity","fuels","renewable energy","nuclear power","fossil fuels"]

fig = go.Figure(data=[
    go.Bar(name='Conservative', x=Words, y=[20292,9141,6995,6582,1070,11491,13801,2339,1536,4368,466]),
    go.Bar(name='Lib Dems', x=Words, y=[4283,2839,2426,1795,274,2300,1727,404,495,1001,123]),
    go.Bar(name='Green', x=Words, y=[327,370,330,227,184,85,68,78,77,49,74]),
    go.Bar(name='Labour', x=Words, y=[20180,10749,10967,7988,985,11607,13347,2387,2059,4567,470])
])
# Change the bar mode
fig.update_layout(barmode='group')
fig.show()

username = 'GemmaThornley' 
api_key = 'tkCXLQ3xImGn7POF3DZ7'
chart_studio.tools.set_credentials_file(username=username, api_key=api_key)
import chart_studio.plotly as py
py.plot(fig, filename = 'Next Graph', auto_open=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5b509795-6650-402a-b2e3-1eb5a0787790" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5b509795-6650-402a-b2e3-1eb5a0787790")) {
#                     Plotly.newPlot(
#                         '5b509795-6650-402a-b2e3-1eb5a0787790',
# ...

# %%
import plotly.graph_objects as go
Words=["environmental","carbon","climate change","emissions","fossil fuel","sustainable","electricity","fuels","renewable energy","nuclear power","fossil fuels"]

fig = go.Figure(data=[
    go.Bar(name='Conservative', x=Words, y=[0.0000177681,0.0000080041,0.0000061250,0.0000057633,0.0000009369,0.0000100618,0.0000120844,0.0000020481,0.0000013450,0.0000038247,0.0000004080]),
    go.Bar(name='Labour', x=Words, y=[0.0000203357,0.0000108319,0.0000110516,0.0000080496,0.0000009926,0.0000116965,0.0000134500,0.0000024054,0.0000020749,0.0000046022,0.0000004736])
])
# Change the bar mode
fig.update_layout(barmode='group')
fig.show()

username = 'GemmaThornley' 
api_key = 'tkCXLQ3xImGn7POF3DZ7'
chart_studio.tools.set_credentials_file(username=username, api_key=api_key)
import chart_studio.plotly as py
py.plot(fig, filename = 'BEtter Graph', auto_open=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2bccb212-5039-40d2-a7bc-0d9db0d0edf4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2bccb212-5039-40d2-a7bc-0d9db0d0edf4")) {
#                     Plotly.newPlot(
#                         '2bccb212-5039-40d2-a7bc-0d9db0d0edf4',
# ...
